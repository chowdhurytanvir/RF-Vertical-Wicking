# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# %%
pd.read_csv("Vertical_Wicking.csv")
# Out:
#              L      t  Angle        Sx        Sy  Diameter   Height  \
# 0     0.002092   0.17     45  0.000037  0.000073   0.00001  0.00005
# 1     0.002470   0.22     45  0.000037  0.000073   0.00001  0.00005
# 2     0.002781   0.27     45  0.000037  0.000073   0.00001  0.00005
# 3     0.003071   0.32     45  0.000037  0.000073   0.00001  0.00005
# 4     0.003321   0.37     45  0.000037  0.000073   0.00001  0.00005
# 5     0.003544   0.42     45  0.000037  0.000073   0.00001  0.00005
# 6     0.003787   0.47     45  0.000037  0.000073   0.00001  0.00005
# 7     0.004016   0.52     45  0.000037  0.000073   0.00001  0.00005
# 8     0.004205   0.57     45  0.000037  0.000073   0.00001  0.00005
# 9     0.004374   0.62     45  0.000037  0.000073   0.00001  0.00005
# 10    0.004536   0.67     45  0.000037  0.000073   0.00001  0.00005
# 11    0.004718   0.72     45  0.000037  0.000073   0.00001  0.00005
# 12    0.004914   0.77     45  0.000037  0.000073   0.00001  0.00005
# ...

# %%
f = open('Vertical_Wicking.txt')
f.readline()  # skip the header
data = np.loadtxt(f)

# %%
#from numpy import genfromtxt
#data = genfromtxt('Vertical_Wicking.csv', delimiter=',')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
# Out:
# C:\Users\Anaconda\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
X = data[:, 1:]  # select columns 1 through end
y = data[:, 0]

# %%
training_size=0.3
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1-training_size,random_state=42)

# %%
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (401, 8) (401,)
# (936, 8) (936,)

# %%
forest_model = RandomForestRegressor(random_state=2)
forest_model.fit(X_train, y_train)
melb_preds = forest_model.predict(X_test)
print(mean_absolute_error(y_test, melb_preds))
# Out:
# 0.0004062887705354082

# %%
forest_model.score(X_test, y_test)
# Out:
# 0.8711133953784675

# %%
from sklearn.metrics import r2_score
r2_score(y_test, melb_preds)
# Out:
# 0.8711133953784675

# %%
plt.scatter(y_test, melb_preds)
plt.axis([0.0015, .0085, 0.0015, .0085])
plt.xlabel('Wicking Front (m)',fontsize=14)
plt.ylabel('Predicted Wicking Front (m)',fontsize=14) 
plt.savefig('Training Size 40%.jpg',dpi=1000) ## svg for high quality. Change dpi for higher quality
